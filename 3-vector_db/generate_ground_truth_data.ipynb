# %% [markdown]
# ## Generate ground truth file for evaluation
# Purpose of this code is to generate ground_truth_data.csv

# %%
from openai import OpenAI
from tqdm.auto import tqdm
from urllib.request import urlopen
import cloudpickle as cp
import json
#client = OpenAI()

# %%
import requests 

docs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

# %% [markdown]
# ## Generate unique IDs for Documents
# To accurately track relevant documents, each document is assigned a unique ID. By maintaining consistent IDs, we can manage changes and updates to the document set without affecting the evaluation process. This helps know which answer goes with which question.

# %%
import hashlib

def generate_document_id(doc):
    # combined = f"{doc['course']}-{doc['question']}"
    combined = f"{doc['course']}-{doc['question']}-{doc['text'][:10]}" # Concatenate Document Attributes
    hash_object = hashlib.md5(combined.encode()) # Use the MD5 hashing algorithm to create a hash from the concatenated string. 
    hash_hex = hash_object.hexdigest()
    document_id = hash_hex[:8] # Extract a Substring of the Hash
    return document_id #Assign the ID to the Document using the Hash

# %%
for doc in documents:
    doc['id'] = generate_document_id(doc)

# %%
with open('documents-with-ids.json', 'wt') as f_out:
    json.dump(documents, f_out, indent=2)

# %%
# !head documents-with-ids.json
# Out:
# [
#   {
#     "text": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  \u201cOffice Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon\u2019t forget to register in DataTalks.Club's Slack and join the channel.",
#     "section": "General course-related questions",
#     "question": "Course - When will the course start?",
#     "course": "data-engineering-zoomcamp",
#     "id": "c02e79ef"
#   },
#   {
#     "text": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",

# %% [markdown]
# ## Use LLM to generate user queries based on documents
# This acts as an alternative to human annotation, which is the better approach to generate ground truth data.

# %%
prompt_template = """
You emulate a student who's taking our course.
Formulate 5 questions this student might ask based on a FAQ record. The record
should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as fewer words as possible from the record. 

The record:

section: {section}
question: {question}
answer: {text}

Provide the output in parsable JSON without using code blocks:

["question1", "question2", ..., "question5"]
""".strip()

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)

    response = client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content
    return json_response

# %%
#for each doc, we generate queries and save the doc-question paires
for doc in tqdm(documents): 
    doc_id = doc['id']
    if doc_id in results:
        continue

    questions = generate_questions(doc)
    results[doc_id] = questions
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 7
#       4 if doc_id in results:
#       5     continue
# ----> 7 questions = generate_questions(doc)
#       8 results[doc_id] = questions
#
# Cell In[15], line 4, in generate_questions(doc)
#       1 def generate_questions(doc):
#       2     prompt = prompt_template.format(**doc)
# ----> 4     response = client.chat.completions.create(
#       5         model='gpt-4o',
#       6         messages=[{"role": "user", "content": prompt}]
#       7     )
#       9     json_response = response.choices[0].message.content
#      10     return json_response
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/resources/chat/completions.py:643, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     609 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     610 def create(
#     611     self,
#    (...)
#     641     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643     return self._post(
#     644         "/chat/completions",
#     645         body=maybe_transform(
#     646             {
#     647                 "messages": messages,
#     648                 "model": model,
#     649                 "frequency_penalty": frequency_penalty,
#     650                 "function_call": function_call,
#     651                 "functions": functions,
#     652                 "logit_bias": logit_bias,
#     653                 "logprobs": logprobs,
#     654                 "max_tokens": max_tokens,
#     655                 "n": n,
#     656                 "parallel_tool_calls": parallel_tool_calls,
#     657                 "presence_penalty": presence_penalty,
#     658                 "response_format": response_format,
#     659                 "seed": seed,
#     660                 "service_tier": service_tier,
#     661                 "stop": stop,
#     662                 "stream": stream,
#     663                 "stream_options": stream_options,
#     664                 "temperature": temperature,
#     665                 "tool_choice": tool_choice,
#     666                 "tools": tools,
#     667                 "top_logprobs": top_logprobs,
#     668                 "top_p": top_p,
#     669                 "user": user,
#     670             },
#     671             completion_create_params.CompletionCreateParams,
#     672         ),
#     673         options=make_request_options(
#     674             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     675         ),
#     676         cast_to=ChatCompletion,
#     677         stream=stream or False,
#     678         stream_cls=Stream[ChatCompletionChunk],
#     679     )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/_base_client.py:978, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     975 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     977 try:
# --> 978     response = self._client.send(
#     979         request,
#     980         stream=stream or self._should_stream_response_body(request=request),
#     981         **kwargs,
#     982     )
#     983 except httpx.TimeoutException as err:
#     984     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /usr/local/python/3.10.13/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File /usr/local/python/3.10.13/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# To save some quota, we directly load the pre generated doc-queries pairs :)

# %%
# !pip install cloudpickle
# Out:
# Collecting cloudpickle
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: cloudpickle
# Successfully installed cloudpickle-3.0.0

# %%
gen_qs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/raw/main/03-vector-search/eval/results.bin'

# %%
loaded_pickle_object = cp.load(urlopen(gen_qs_url))

# %%
#sample questions
loaded_pickle_object['1f6520ca']
# Out:
# '["Where can I find the prerequisites for this course?", "How do I check the prerequisites for this course?", "Where are the course prerequisites listed?", "What are the requirements for joining this course?", "Where is the list of prerequisites for the course?"]'

# %%
parsed_resulst = {}

for doc_id, json_questions in results.items():
    parsed_resulst[doc_id] = json.loads(json_questions)

# %%
parsed_resulst
# Out:
# {'c02e79ef': ['When exactly does the course start?',
#   "How can I subscribe to the course's public Google Calendar?",
#   'What do I need to do before the course starts?',
#   'Where can I join the course announcements channel?',
#   'Which Slack workspace and channel should I join for the course?'],
#  '1f6520ca': ['What prerequisites are required for this course?',
#   'Where can I find the prerequisite information?',
#   'Does the course have any prerequisites?',
#   'Where are the details about the prerequisites listed?',
#   'Can you tell me the prerequisite link for this course?'],
#  '7842b56a': ['Can I submit homework if I join after the course starts?',
#   'If I miss the registration deadline, can I still submit homework?',
#   'Is it possible to join the course after it has started?',
#   'Are there deadlines for submitting final projects if I join late?',
#   'Can I register for the course after the start date and still participate fully?'],
#  '0bbf41ec': ["I registered for the Data Engineering Bootcamp but haven't received a confirmation email. Is that normal?",
#   'Is it necessary to wait for the confirmation email to start the Data Engineering Bootcamp?',
#   "Can I begin learning and submitting homework if I haven't officially registered for the course?",
#   'Do I need to check my registration status to join the Data Engineering Bootcamp?',
#   "What's the purpose of registration if it doesn't confirm my participation in the Data Engineering Bootcamp?"],
#  '63394d91': ['What should I install before our course begins?',
#   'How do I prepare for this course in advance?',
#   'Which software should I set up before starting the course?',
#   'What are the prerequisites for starting the course?',
#   'How can I ensure I’m ready for the course topics?'],
#  '2ed9b986': ['How many Zoom Camps are held each year?',
#   'Are the Zoom Camps for different courses?',
#   'When is the Data-Engineering Zoomcamp conducted each year?',
#   'Is there only one live cohort for each Zoomcamp per year?',
#   'Can I take Zoom Camps at my own pace without the certificate?'],
#  '93e2c8ed': ['What is replacing Prefect in the 2024 cohort?',
#   'What change has been made to the terraform videos for 2024?',
#   'Was Airflow used in the 2023 edition of the course?',
#   'Will Mage AI be used in the 2024 cohort?',
#   'Has Prefect been previously used in the 2023 cohort?'],
#  'a482086d': ['Is it possible to access the course materials after the course ends?',
#   'Can I still review the homeworks once the course is finished?',
#   'Will the course content be available for future reference?',
#   'Can I prepare for the next cohort after completing the course?',
#   'Am I allowed to start my capstone project after the course concludes?'],
#  'eb56ae98': ['Can I receive support while taking the self-paced course?',
#   'If I have questions in the self-paced course, where should I check first?',
#   'Is there a way to automatically search for answers in the Slack channel?',
#   'Should I rely solely on @ZoomcampQABot for my questions?',
#   'Is the Slack channel available for self-paced course participants?'],
#  '4292531b': ['Which YouTube playlist contains all the main videos?',
#   'Where can I find additional year-specific videos for office hours?',
#   "Is the Main 'DATA ENGINEERING' playlist pinned somewhere?",
#   'How can I access each video directly from the GitHub repository?',
#   'What should I refer to in order to reach the main videos?'],
#  'ea739c65': ['How many hours per week should I plan to spend on this course?',
#   'What is the weekly time commitment for this course?',
#   'Can you tell me the estimated weekly hours for this course?',
#   'How much time will I need to dedicate weekly to this course?',
#   'What is the typical weekly workload for this course?'],
#  'cb257ee5': ['Can I obtain a certificate if I complete the course at my own pace?',
#   'Is it possible to earn a certificate by finishing the course independently?',
#   'Do I need to be part of a live cohort to receive a certificate?',
#   'Will I get a certificate if I submit my projects in self-paced mode?',
#   'Are certificates awarded for completing the course individually without a live cohort?'],
#  '04aa4897': ['How can students participate in office hour or workshop sessions if the Zoom link is only shared with instructors?',
#   'Where will the YouTube Live link for the office hour sessions be posted?',
#   'How should students submit their questions during office hour or workshop sessions?',
#   "Why shouldn't students post their questions in the chat during live sessions?",
#   'Where can students find the video URL for the live sessions before they start?'],
#  '9681be3b': ['Will the workshop session be recorded if I miss it?',
#   'Are office hours available for viewing later?',
#   'Can I rewatch the office hours sessions at a convenient time?',
#   "If I can't attend, can I still access the recorded office hours?",
#   'Is it possible to view workshops after the live session is done?'],
#  'a1daf537': ['Where can I find the latest deadlines for homework and projects?',
#   'How will I know if there are extensions on homework deadlines?',
#   'Is there a place where updated project deadlines are posted?',
#   'Who should I check with for any news about homework deadlines?',
#   'Will the spreadsheet always show the updated homework deadlines?'],
#  'be5bfee4': {'questions': ['Can I submit my homework after the deadline if the form is still open?',
#    'Are there any exceptions for late homework submissions?',
#    'How can I confirm my homework submission after the due date?',
#    'What happens if I miss the homework submission deadline?',
#    'Where can I check the submission timestamp for my homework?']},
#  '0e424a44': ['What is the URL we need to submit for homework?',
#   'Where should we put our code for homework submission?',
#   'Can I use GitLab for submitting my homework?',
#   'Is my personal GitHub repository acceptable for homework?',
#   'How is our homework location verified?'],
#  '29865466': ['How are homework assignments graded in the course?',
#   "Where can I see the total points I've earned across all assignments and activities?",
#   'What types of activities can earn me points besides homework?',
#   'How much is submitting to the FAQ section worth in terms of points?',
#   'What is the URL to the Slack message that discusses the points system?'],
#  '016d46a1': ['How do I find out my display name on the leaderboard?',
#   'What is the URL to check my display name?',
#   'Where can I edit my course profile?',
#   'How can I change my display name for the leaderboard?',
#   'What steps do I follow to log in and see my display name?'],
#  '47972cb1': ['Is Python 3.9 still the recommended version to use in 2024?',
#   'Why is Python 3.9 recommended?',
#   'Can I use Python 3.10 for the course?',
#   'Will Python 3.11 work for the course?',
#   'What is the advantage of using Python 3.9 for the course?'],
#  'ddf6c1b3': ['Should I use my local machine or a virtual machine for my environment?',
#   'What should Windows users be aware of when setting up their environment locally?',
#   'If I prefer to work locally, which week should I start with?',
#   'Which services can I use to set up a virtual machine for this course?',
#   'Why might someone choose to work on a virtual machine instead of a local machine?'],
#  'ac25d3af': ['Can I use GitHub Codespaces instead of cli/git bash for data ingestion and Docker file creation?',
#   'Does GitHub Codespaces come with pre-installed tools like Docker and Python?',
#   'Is it possible to open any GitHub repository in a GitHub Codespace?',
#   'Are Linux computing resources available in GitHub Codespaces?',
#   'Does GitHub Codespaces support Docker Compose?'],
#  '251218fc': ['Do I have to use GitHub codespaces if I already have my own setup?',
#   'Can I complete the course using my own laptop?',
#   'Is it mandatory to use GCP VM for the course?',
#   'Are there any restrictions on using personal environments for the course?',
#   'Is Github codespaces the only recommended platform for this course?'],
#  '3c0114ce': ['Is it necessary to use both GitHub Codespaces and GCP for this course?',
#   'Can I use just GCP or should I also consider GitHub Codespaces?',
#   'What are the benefits of using GCP over GitHub Codespaces for this course?',
#   'Why is BigQuery important for this course?',
#   'Is setting up a local environment sufficient for most of the course?'],
#  'f43f5fe7': ['How do I open the Run command window on a Windows machine?',
#   'Where can I find the registry values related to GCP VM connection issues?',
#   'What is the registry value that needs to be changed in Registry Editor to solve GCP VM connection issues?',
#   'How can I open the Registry Editor on a Windows machine?',
#   'What is an alternative solution to changing the registry values for solving GCP VM connection issues in VSCode?'],
#  'd061525d': ['Why are we using GCP for the course?',
#   'Are we restricted to using only GCP for our projects?',
#   'Is GCP the only cloud provider offering a free trial and credits?',
#   'Since we are using BigQuery, do we have to stick to GCP?',
#   'What do I need to sign up for the free GCP account?'],
#  '1cd01b2c': ['Do I have to pay for cloud services?',
#   'Is there a cost for using GCP in this course?',
#   'Can I use cloud services for free during the course?',
#   'Is there a free trial for GCP that I can use?',
#   'Will I incur any charges for cloud services if I use GCP?'],
#  'e4a7c3b0': ['Is it feasible to complete this course without using any cloud providers?',
#   'Can all the course materials be run locally if GCP is not accessible?',
#   'Will there be a guide for setting up a home lab if GCP is unavailable?',
#   'Is BigQuery the only component in the course that cannot be run locally?',
#   'Are there local alternatives for everything in the course that usually uses GCP?'],
#  '7cd1912e': {'questions': ['Can I use AWS instead of GCP for this course?',
#    'If I use AWS, how should I handle the course content based on GCP?',
#    'How will my final project be evaluated if I adapt it to AWS?',
#    'What should I do if I need help while using AWS?',
#    'Are there coursemates who can assist me with AWS-related issues?']},
#  '52393fb3': ['Are there any live Zoom calls planned outside the Office Hour?',
#   'Will there be additional sessions apart from the Office Hour?',
#   'Can we expect any live sessions during the Capstone period?',
#   'How will I know if there are extra Zoom calls for questions?',
#   'Is it possible to have live calls besides the Office Hour for more clarity?'],
#  '10515af5': ['Are we going to use the same NYC Trip data as last year?',
#   'Will the data source for our project be different this year?',
#   'Is the January 2021 NYC Trip data still relevant for our course?',
#   'Are we updating the NYC Trip data to 2022?',
#   'Can I find the NYC Trip data for the project here?'],
#  'cdb86a97': ['Was the 2022 repository removed?',
#   'Where can I find the 2022 materials?',
#   'Is the 2022 content still accessible?',
#   'Have you deleted the 2022 repository?',
#   'Did you relocate the 2022 resources?'],
#  '3e0114ad': ['Can I utilize different tools for my final project?',
#   'Is it allowable to choose my preferred tool for the project?',
#   'Am I restricted to specific tools for the final project?',
#   'Can any software be used for completing the final project?',
#   'May I select any tool for my project submission?'],
#  'b2799574': ['Can I use Airflow instead of Mage for the course projects?',
#   'May I choose AWS or Snowflake as an alternative to GCP products?',
#   'Is it acceptable to use Tableau instead of Metabase for the assignments?',
#   'Can I use my preferred tools instead of the ones specified in the course?',
#   'If I use different tools, will I receive support from the course instructors?'],
#  '2f19301f': ['Can we star the repository to contribute to the course?',
#   'How should we share the course if we find it useful?',
#   'What can we do if we know how to improve the repository?',
#   'Is creating a PR a way to contribute to the course?',
#   'What actions can we take to help besides starring the repo?'],
#  '7c700adb': ['Is the course compatible with Windows?',
#   'Can I use macOS for the course?',
#   'Will Linux work well for this course?',
#   'Do I need a specific OS to complete the course?',
#   'Have students used different OSes successfully before?'],
#  '44b14808': ['How have past students solved issues with shell scripts on Windows?',
#   'What is recommended for Windows users to handle *.sh files in later modules?',
#   'Why do Windows users face issues with shell scripts in module-05 and the RisingWave workshop?',
#   'Are there any records of how previous cohorts managed to work with *.sh files on Windows?',
#   'Is using WSL essential from the beginning to avoid problems with *.sh scripts on Windows?'],
#  '76e4baf6': ['Are there any recommended books for this course?',
#   'Can you suggest some additional resources for the course?',
#   'Is there a list of recommended resources available?',
#   'Where can I find additional reading materials?',
#   'Do you have a document with suggested books and resources?'],
#  '48b533a8': ['Can you explain what Project Attempt #1 and Project Attempt #2 are?',
#   'What happens if I miss the first project deadline?',
#   'Is there a second chance to submit the project if I fail the first attempt?',
#   'How many attempts do we have for submitting the project?',
#   'What should I do if I am late for the first project submission?'],
#  '954044d1': ['What is the first step I should take when troubleshooting an issue?',
#   'How can I use browser functionalities to help troubleshoot issues?',
#   "Where should I post my question if I'm stuck after trying to troubleshoot on my own?",
#   'Why should I avoid using screenshots when asking technical questions in the course?',
#   "What should I do if a reinstalled application still doesn't resolve the issue?"],
#  'a820b9b3': ['When should I ask a question if the troubleshooting guide doesn’t help?',
#   'What information should I include when asking a coding question?',
#   'Should I mention my OS and the commands I ran while asking a question?',
#   'How should I describe the error I got when asking for help?',
#   'Why is it important to include what I tried that did not work in my question?'],
#  'f2945cd2': {'questions': ['How do I clone the course repository from GitHub?',
#    'What resources can I use to set up my own GitHub repositories?',
#    'Which files should I avoid saving to a Git repository?',
#    'Why should I never store passwords or keys in a Git repository?',
#    'Where can I learn more about basic Git commands and troubleshooting?']},
#  'eb9d376f': ['What should I do if I get an error in my Makefile about a missing separator?',
#   'How can I fix a Makefile error related to tabs and spaces in VS Code?',
#   'What is the solution when Makefile throws an error about missing separator?',
#   'How do I resolve an error with missing separators in my Makefile project?',
#   'What step can I follow to correct a Makefile error due to tab versus space issues in VS Code?'],
#  '72f25f6d': ['How can I open an HTML file with a Windows browser from Linux on WSL?',
#   'What is the command to open an HTML file with a browser from WSL?',
#   'Which command allows customization of the browser used in WSL?',
#   'What package should be installed to open HTML files from Linux on WSL?',
#   'How can I set Firefox as the default browser in WSL?'],
#  'a1e59afc': ['How do I set up Chrome Remote Desktop on a Debian Linux VM instance on Compute Engine?',
#   'Why am I getting ERROR 403: Forbidden when downloading the 2021 Yellow Taxi Trip Records from the TLC website?',
#   'What backup link should I use to download the 2021 Yellow Taxi Trip Records?',
#   "How do I unzip the 'gz' file for the Yellow Taxi Trip Records?",
#   "Which command should I use instead of 'unzip' to decompress a .gz file?"],
#  '71c10610': ['How can I handle taxi data files if they are available as *.csv.gz?',
#   "Why won't the data file store correctly if the file extension is csv.gz?",
#   'What URL contains the yellow taxi data?',
#   'How can I parse the filename from the URL for taxi data?',
#   'How does the pandas read_csv function handle files with csv.gz extensions?'],
#  '17a5aea1': ['Where can I find the data dictionary for Yellow Taxi trips?',
#   'Is there a link to the data dictionary for Green Taxi trips?',
#   'How do I access the data dictionary for NY Yellow Taxi data?',
#   'Can you provide the data dictionary URL for Green Taxi trips?',
#   'What is the link to the Yellow Taxi trip records data dictionary?'],
#  '5a275db7': ['How do I unzip the Taxi Data parquet file?',
#   'What is the command to unzip a gzipped CSV file in the command line?',
#   'How can Parquet files be used directly in a Python script for data ingestion?',
#   'Which line should be added to the main function to work with Parquet files in the script?',
#   'How do I convert a downloaded Parquet file to a CSV in a Python script?'],
#  '7ec0f9b0': ["How do I install wget on Ubuntu if it's not recognized as a command?",
#   "What's the simplest way to install wget on MacOS?",
#   'How can I install wget on Windows using Chocolatey?',
#   'Is there an alternative Python method to use wget, and how do I install it?',
#   'Can I use a web browser to download a file if wget is not available?'],
#  'bb1ba786': ["What should I do if I get an error 'cannot verify <website> certificate' when using wget on MacOS?",
#   'How can I run wget commands in a Jupyter Notebook or CLI on MacOS?',
#   'How do I use the Python wget library to verify a website certificate?',
#   'What is the --no-check-certificate option for wget used for in MacOS?',
#   'How can I troubleshoot wget certificate verification errors on MacOS?'],
#  '2f83dbe7': ['How can I use the backslash as an escape character in Git Bash for Windows?',
#   'What should I type in Git Bash to use the backslash as an escape character?',
#   'Is it necessary to add the backslash escape character setting to .bashrc in Git Bash for Windows?',
#   'What is the command Alexey uses to set the backslash as an escape character in Git Bash?',
#   'Which terminal command changes the escape character to a backslash in Git Bash for Windows?'],
#  '543ff080': ['Where can I find instructions to store secrets in GitHub Codespaces?',
#   'How do I store account-specific secrets for GitHub Codespaces?',
#   'What is the resource for managing secrets in GitHub Codespaces?',
#   'Where are the steps for storing secrets available in GitHub Codespaces?',
#   'How do I handle secrets for GitHub Codespaces?'],
#  'd407d65b': ['How can I resolve the error: Cannot connect to Docker daemon at unix:///var/run/docker.sock?',
#   'What should I check if Docker cannot start the daemon?',
#   'What is the command to update WSL to address Docker issues?',
#   'Is there a specific Powershell command to fix Docker daemon issues?',
#   'What might be causing Docker to fail to connect to the daemon?'],
#  'c9375c56': ["I am using Windows 10 Home, how can I get Docker running if I can't enable Hyper-V?",
#   "What should I do if I encounter a 'WslRegisterDistribution failed with error: 0x800701bc' while installing WSL2?",
#   'I am on Windows 10 Pro, how can I enable Hyper-V to use Docker?',
#   'Why does Docker give an error saying it cannot find the file specified when trying to connect on a Windows system?',
#   'Where can I find detailed instructions for installing WSL2 on Windows 11?'],
#  'e866156b': ["What is the reason for encountering a 'requested access to the resource is denied' error when performing a docker pull?",
#   'Can I pull Docker images without logging in during the Data Engineering Zoomcamp?',
#   "How do I resolve the error 'repository does not exist or may require docker login' when pulling a Docker image?",
#   "Why do I get a 'permission denied' error when creating a PostgreSQL Docker container with a mounted volume on macOS M1?",
#   'How can I fix compatibility issues with PostgreSQL Docker containers on macOS M1 when using Rancher Desktop?'],
#  '16370470': ["What should I do if I can't delete a local folder mounted to a Docker volume?",
#   'How do I fix access errors due to a Docker-created folder?',
#   'What command can I use to delete a folder created by a Docker container?',
#   'Why can’t I delete a folder that is owned by user 999 in Docker?',
#   'How do I remove a protected folder created by a PostgreSQL container?'],
#  '316df755': ['How can I resolve Docker not starting or being stuck in settings on Windows 10/11?',
#   'Where can I download the latest version of Docker for Windows?',
#   'What should I do if Docker is stuck on starting?',
#   'How do I switch containers in Docker on Windows?',
#   'What are the requirements for running Docker on Windows 10/11 Pro Edition?'],
#  'f3aa9252': ['Where is it recommended to run docker commands, the Windows file system or a Linux distribution in WSL?',
#   'Can I run Docker with WSL2 on Windows 10 Home Edition?',
#   'What should I do if Docker remains stuck after ensuring WSL2 or Hyper-V is set up correctly?',
#   'Is it possible to make Docker work on Windows Home Edition with WSL2?',
#   'Where can I find a tutorial to set up Docker with WSL2 on Windows Home Edition?'],
#  'a4abe7a5': ['What is the recommended location to store code for optimal file system performance when using Docker?',
#   'Where can I find detailed information about Docker best practices?',
#   'Why does Docker use WSL2 backend by default for Windows 10 Home and Windows 11 Home?',
#   "Which operating system's default Linux distro should I use to store code for Docker?",
#   'Is there a resource that details best practices for Docker usage?'],
#  'fb930700': ["What error might I encounter when running 'docker run -it ubuntu bash' on Windows?",
#   "How can I fix the 'input device is not a TTY' error when using Docker on Windows?",
#   'What command should be used to run Docker on Windows if mintty is being used?',
#   'How can I avoid repeatedly typing the winpty prefix for Docker commands on Windows?',
#   'Where should I add an alias for Docker to always use winpty on Windows?'],
#  'aa187680': ['How do I resolve a pip install issue on a Docker container in Windows where the error mentions a Temporary failure in name resolution?',
#   "What's the recommended command to run a Docker container with Python 3.9 and set DNS to 8.8.8.8?",
#   "Why am I seeing a 'Failed to establish a new connection' error when trying to pip install packages in Docker on Windows?",
#   "What can I do if pip install in my Docker container fails due to a connection broken by 'NewConnectionError'?",
#   'Is there a way to specify DNS settings when running a Docker container to avoid pip install issues on Windows?'],
#  'b000e899': ['What should I do if the ny_taxi_postgres_data folder is empty when using Docker on Windows?',
#   'How can I make the ny_taxi_postgres_data folder visible in VS Code after running the Docker script?',
#   'Which Docker command should I use to solve the issue of an empty ny_taxi_postgres_data folder on Windows?',
#   'What parameter should I quote in the Docker command to make ny_taxi_postgres_data files visible?',
#   'What environment variables need to be set when running the Docker command for ny_taxi_postgres_data on Windows?'],
#  '9c66759f': ['How do I set up Docker on a Mac for this course?',
#   "I've read that the method for setting up Docker on macOS might be outdated, is that true?",
#   'What is a reliable way to install Docker on my Mac?',
#   "Has Docker's licensing model affected the setup process on macOS?",
#   'Should I follow the article or download Docker directly from the website?'],
#  'e3106e07': ['How can I solve the permission error when changing permissions of /var/lib/postgresql/data in Docker?',
#   'What is the command to create a local Docker volume to be used for Postgres data directory?',
#   'How can I ensure my Docker volume setup for Postgres is correct in Docker Desktop?',
#   'What should I do if I get the error \'directory "/var/lib/postgresql/data" exists but is not empty\'?',
#   'What are the environment variables required to run a Postgres container in Docker using Docker volumes?'],
#  '72229da5': ["What should I do if the volume mapping method from the course video doesn't work for me on Windows?",
#   'How can I specify a volume path for Docker on Windows to avoid errors?',
#   'How can I avoid issues with spaces in the folder path when using Docker on Windows?',
#   "What variations of the 'docker run' command can I use on Windows for mounting volumes to avoid invalid reference format errors?",
#   'What should I do if Docker automatically creates an incorrect folder for volume mapping on Windows?'],
#  '58c9f99f': ["What should I do if I get 'invalid mode' error in Docker?",
#   'What is the solution to Docker mounting path errors for Postgres?',
#   "How can I fix the 'invalid mode' error when using Docker in Module 1?",
#   'What are the correct paths for mounting Postgres in Docker?',
#   "How to resolve 'Error response from daemon' in Docker for Git path in Module 1?"],
#  'bc42139a': ['What can I do if I encounter an error while creating the buildmount source path in Docker?',
#   'How should I run the Docker command the second time without encountering the buildmount source path error?',
#   "Why do I get a 'file exists' error when running the Docker command again?",
#   'What changes need to be made to the Docker command to avoid the directory creation error on subsequent runs?',
#   'Is it necessary to mount the path every time I run the Docker container for PostgreSQL?'],
#  'a146e3ee': ["What is the cause of the Docker build error: error checking context: 'can't stat '/home/user/repos/data-engineering/week_1_basics_n_setup/2_docker_sql/ny_taxi_postgres_data''?",
#   "What command triggered the 'can't stat' error while building the Docker image?",
#   'Why did changing the user ID of the ny_taxi_postgres_data directory cause a permission issue?',
#   "How can one fix the 'can't stat' error when running the docker build command?",
#   'Where can I find more detailed information on fixing the Docker build error related to checking context?'],
#  '593a85ba': ["What should I do if I get 'error waiting for container: context canceled' on Docker?",
#   'How can I verify if Docker was installed via snap?',
#   "What does 'sudo snap status docker' do?",
#   'What is the correct way to install Docker if the snap command is unknown?',
#   "Why might 'Bind for 0.0.0.0:5432 failed' occur in Docker?"],
#  '50bd1a71': ['What could be the cause of a build error when checking context in Docker on PopOS Linux?',
#   "Why might a folder seem empty but actually isn't when using Docker on PopOS Linux?",
#   "How can I resolve an issue with a can't stat error in Docker on PopOS Linux?",
#   'What command can I use to add permission for everyone to a folder for Docker?',
#   'Can you provide an example command to add permission to a folder for Docker?'],
#  'f409f751': ["What should I do if I encounter 'permission denied' when trying to rebuild a Docker container on Ubuntu/Linux?",
#   'How do I grant permissions to the newly created folder hosting Docker files to resolve build errors?',
#   "What is the command to set folder permissions to avoid 'failed to read dockerfile' errors when using Docker?",
#   'Why might I need to use the chmod command when rebuilding my Docker pipeline?',
#   'What permissions should I set if chmod 755 does not resolve the permission denied issue in Docker?'],
#  '7d217da3': ['How can I find the name of a Docker network?',
#   'What command should I use to list Docker networks?',
#   'Is there a command to display Docker networks?',
#   'Which command lists all available Docker networks?',
#   'How do I view the names of existing Docker networks?'],
#  '09081824': ["How can I resolve the error message indicating that the container name 'pg-database' is already in use by another container?",
#   'What command should I use if I see a conflict error when restarting a docker image with a network name?',
#   'What steps should I follow to remove a container that is causing a name conflict in Docker?',
#   "Is there an alternative to using 'docker run' to restart a Docker image without removing the container?",
#   "What should I do if a container with the name 'pg-database' is already running and I want to reuse that name?"],
#  '4df80c55': ['What error might I encounter when translating the host name using Docker and Docker Compose?',
#   "How can I resolve the 'could not translate host name' error in Docker Compose?",
#   'Which network should I use for the ingestion script when encountering connection issues in Docker Compose?',
#   'How do I determine the correct database name for the ingestion script in Docker?',
#   'What is an example of a correct network and database name substitution in Docker Compose?'],
#  '3aee7261': ['How do I enable nested virtualization for Docker on an Intel CPU running MacOS/Windows 11 VM on Linux?',
#   'What command should I run to install Docker on an AMD CPU in a VM on MacOS/Windows 11?',
#   "I'm using an Intel CPU. How do I set up nested virtualization for Docker in a VM?",
#   'Which commands should be used for nested virtualization on AMD CPUs for Docker?',
#   'Is there a specific command to enable nested virtualization on Intel CPUs for Docker on MacOS/Windows 11 VM?'],
#  '6497b659': ['How do I manage Docker containers using VS Code?',
#   'What should I install in VS Code to manage Docker?',
#   'Can VS Code connect to Docker running on WSL2?',
#   'Which command stops a Docker container?',
#   'Where do I find the Docker extension icon in VS Code?'],
#  'a02f2039': ["Why is my Postgres container not accepting any requests and showing 'Database system is shut down'?",
#   "How can I fix the 'connection failed: server closed the connection unexpectedly' error in my Postgres container?",
#   "What should I do if my Postgres container's data directory appears to contain a database but the server is shut down?",
#   'Why does my Postgres server terminate abnormally before or while processing the request?',
#   "What steps should I take when my Postgres container shows 'Database system is shut down' in the logs?"],
#  'c6db65aa': ['How can I install Docker on certain Ubuntu versions?',
#   "What command should I use if Docker can't be installed on my Ubuntu?",
#   'Is there an alternative method for installing Docker on Ubuntu?',
#   'What to do if Docker installation fails on certain Ubuntu versions?',
#   'Can Docker be installed using snap on Ubuntu?'],
#  'f476a606': ['How can I resolve a mounting permission error in Docker-Compose for PostgreSQL?',
#   'What should I do if Docker-Compose creates a new volume instead of using the existing one?',
#   'How do I define a named volume in the Docker-Compose file?',
#   "What command do I use to inspect a Docker volume's location?",
#   'How can I ensure that Docker-Compose uses an existing volume rather than creating a new one?'],
#  'e41b100c': ['Why am I getting an error translating host name to address in Docker-Compose?',
#   'How do I start containers in detached mode using docker-compose?',
#   'Which command can show me the status of all running containers?',
#   'How can I see logs for a specific container in Docker?',
#   'What should I do if pg-database is not listed in the running containers?'],
#  'cd0f9300': ["What should I do if I encounter an error stating 'could not translate host name to address' after executing docker-compose up?",
#   'What steps can I take if I lose my database data and my Ingestion script fails?',
#   'Why is Docker Compose creating its own default network and how can I find its name?',
#   'How do I change the network name argument in my Ingestion script after executing docker-compose up?',
#   'If pgcli continues to fail, what alternative tools can I use for database management?'],
#  '7f845a1c': ["Why does Docker return 'Error response from daemon: network not found' when using docker-compose?",
#   "What can I do if localhost:8080 server shows 'Unable to connect to server: could not translate host name pg-database to address'?",
#   'How can I check all the stopped and running containers in Docker?',
#   'What should I change in my docker-compose.yml if my hostname does not resolve?',
#   'How can I ensure both containers are on the same network in my docker-compose.yml?'],
#  '36e54439': ['How can I persist PGAdmin data when running docker-compose on GCP?',
#   "Why doesn't persisting PGAdmin data to a path work when using docker-compose on GCP?",
#   'What change should I make to ensure PGAdmin data is persistent on GCP?',
#   'Can I use a Docker Volume to make PGAdmin data persist when using docker-compose on GCP?',
#   'How should I configure the volumes for PGAdmin to ensure data persistence on GCP?'],
#  '32e8450c': ["What could cause Docker to crash continuously and show 'failed to fetch extensions'?",
#   "How can I fix Docker if it keeps crashing and won't restart?",
#   'What steps should I take if Docker fails to fetch extensions and stops?',
#   'What should I do if Docker engine stopped and I keep getting error pop-ups?',
#   "Is reinstalling Docker a solution if updating doesn't fix the issue?"],
#  '96606db2': ['How can I persist pgAdmin configuration in Docker-Compose?',
#   "What should be included in the 'volumes' section to persist pgAdmin settings?",
#   'Which folder should be specified for the pgAdmin session settings on the host machine?',
#   "How do I grant the pgAdmin container write access to the 'pgAdmin_data' folder?",
#   'What username and user group does the pgAdmin container run with?'],
#  '0882bfac': ["How can I fix the 'dial unix /var/run/docker.sock: connect: permission denied' error when using Docker-Compose?",
#   "What steps should I follow to allow my user to avoid 'permission denied' errors with Docker-Compose?",
#   'How can I maintain my database connection in pgAdmin across container restarts in Docker-Compose?',
#   'What do I need to add to my docker-compose.yaml file to create a volume for pgAdmin to persist its state?',
#   'Where should I declare the pgAdmin volume in the docker-compose.yaml file to ensure it remembers previous connections?'],
#  '7d067f5c': ['What should I do if docker-compose is still not available after editing .bashrc?',
#   'Why is docker-compose not working after following video 1.4.1 instructions?',
#   'How do I fix docker-compose-linux-x86_64 not being recognized in my VM?',
#   'What is the solution if docker-compose-linux-x86_64 is downloaded instead of docker-compose?',
#   'How can I properly rename docker-compose-linux-x86_64 to use docker-compose command?'],
#  'ff352621': ['How can I resolve the error getting credentials when running docker-compose up -d?',
#   'What package should I install to fix the Docker-Compose error regarding credentials?',
#   'Where can I find more information about resolving the Docker-Compose credentials error?',
#   'What is the command to install the package that resolves the Docker-Compose credentials issue?',
#   'Why am I facing a credentials error when using Docker-Compose up -d?'],
#  '2d653208': ['What should I do if I encounter errors with Docker compose and PostgreSQL setup?',
#   'How do I create a new volume on Docker for my setup?',
#   'What modifications are necessary in the docker-compose.yml file for proper setup?',
#   'When importing a CSV file, what parameter should I set to avoid memory issues?',
#   'Can you outline the steps for executing data ingestion with Docker and pgAdmin?'],
#  'f09ea61e': ['Where can I find the docker config.json file?',
#   'How do I resolve the Docker Compose up -d error related to docker-credential-desktop?',
#   'What should I modify in config.json to fix the docker-credential-desktop error?',
#   'What directory might contain the config.json file for Docker on my system?',
#   'After modifying credsStore to credStore, what is the next step?'],
#  'fbd3d2bb': ['How can I determine which docker-compose binary to download for WSL in this course?',
#   'What is the command to check my system for the appropriate docker-compose binary?',
#   'Which URL should I use to download docker-compose for my system?',
#   "What does the command 'uname -s' return when checking my system for docker-compose?",
#   'How do I use the curl command to download the correct docker-compose binary for WSL?'],
#  '0b014d0c': ['How can I fix the undefined volume error in Docker-Compose on Windows/WSL?',
#   "What should I do if I encounter the error 'service refers to undefined volume' in my docker-compose.yaml file?",
#   'Which section of my docker-compose file should I modify to resolve the invalid compose project error?',
#   "How do I specify a missing volume for 'pgdatabase' in Docker-Compose?",
#   'What should the structure of my docker-compose file look like to include the missing volume?'],
#  'd21bff1d': ['What is causing the initdb permission error when using WSL and Docker?',
#   'How can I resolve directory permissions issues in WSL Docker?',
#   'Why should I use Docker volumes for persistent storage instead of a local drive?',
#   "Is the 'user:' setting necessary when using Docker volumes for postgres?",
#   'How do I configure Docker volumes in the docker-compose.yaml file to avoid permission conflicts?'],
#  '6afb7b55': ['Can you explain why pgadmin might not work when running on Git Bash or a VM in Windows for querying in Postgres?',
#   'What libraries are required if pgadmin is not functioning properly on Git Bash or a Windows VM?',
#   'What is the suggested solution if pgadmin is not working for querying in Postgres on Git Bash or a Windows VM?',
#   'How can I install the required library psycopg2 for querying in Postgres?',
#   'What tool can be used as an alternative to pgadmin for Postgres querying if issues persist?'],
#  'b51c3b82': ["Why does 'Insufficient system resources exist' error occur in WSL?",
#   'How can I update the Windows Terminal to resolve WSL issues?',
#   'What steps should be taken to ensure Windows security updates are applied?',
#   'Where can I find updates for the Windows Terminal in the Microsoft Store?',
#   'Why is it important to restart the system after applying updates for WSL issues?'],
#  '326af690': ['What should I do if WSL integration with Ubuntu stopped unexpectedly with exit code 1?',
#   'How can I fix a DNS issue causing WSL integration problems on Windows?',
#   'What registry commands can I use to resolve the DNS issue for WSL on Windows?',
#   'What is an alternative solution to fix WSL integration issues besides DNS commands?',
#   "What should I do if I see the error 'bash: conda: command not found'?"],
#  'c2ec9047': ['How can I resolve an issue when trying to run the GPC VM through SSH in WSL2?',
#   'Why might I be experiencing errors when running SSH commands from WSL2?',
#   'What command could I use to avoid permission errors when running SSH commands in WSL2?',
#   "What should I do if adjusting permissions and using sudo doesn't resolve my SSH issues in WSL2?",
#   'How can I move my .ssh keys from Windows to the home directory in WSL2 to resolve SSH issues?'],
#  '3b711e73': ['How do I resolve the issue of WSL2 not referencing the correct .ssh/config path?',
#   'Where should I create the .ssh/config file in WSL2?',
#   "What steps do I follow to fix 'Could not resolve host name' error in WSL2?",
#   'Can you explain how to configure the .ssh/config file for WSL2?',
#   'What details should the config file in WSL2 contain to resolve host name issues?'],
#  'cfe07c9d': ['How can I resolve a PGCLI connection failure on port 5432?',
#   "What should I change to fix the error: 'could not receive data from server: Connection refused' in PGCLI?",
#   "How do you modify the PGCLI command to solve the 'could not send SSL negotiation packet' issue?",
#   'What is the correct PGCLI command to connect to a local PostgreSQL server on port 5432?',
#   'Which parameters need to be adjusted in PGCLI for a successful connection to the ny_taxi database?'],
#  'acf42bb8': ['What might cause the PGCLI --help error in Module 1?',
#   'How can I troubleshoot installation errors in Module 1?',
#   'What should I do if I encounter an error using PGCLI?',
#   'Where can I find help for the PGCLI --help error?',
#   'Could an installation issue be causing PGCLI --help to fail?']}

# %%
doc_index = {d['id']: d for d in documents}

final_results = []

for doc_id, questions in parsed_resulst.items():
    course = doc_index[doc_id]['course']
    for q in questions:
        final_results.append((q, course, doc_id))

# %%
import pandas as pd

# %% [raw]
# df = pd.DataFrame(final_results, columns=['question', 'course', 'document'])

# %%
df.to_csv('ground-truth-data.csv', index=False) #save ground truth to a file
